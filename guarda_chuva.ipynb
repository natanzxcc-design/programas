# %% [markdown]
# <a href="https://colab.research.google.com/github/natanzxcc-design/programas/blob/main/guarda_chuva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("em uma nota de 0 a 10 qual a chance de chover na sua região: ")

chuva = int (input("a chance são "))
if chuva  <0 or chuva  >10:
  guardac = "resposta invalida"

else:

 if chuva >= 6:
    guardac = "leve guarda chuva"

 else:
  guardac = "não precisa leva guarda chuva"

print(guardac)
# Out:
# em uma nota de 0 a 10 qual a chance de chover na sua região:
# a chance são 4
# não precisa leva guarda chuva
